# %%
import dotenv
from agents import Agent, Runner,function_tool
import requests
import os

print(os.getenv("OPENAI_API_KEY"))
# Out:
# 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

# %%
@function_tool
def get_popular_movies():
    """인기영화 정보를 가져오는 api 호출 함수입니다.
    모든 영화 정보 리스트를 가져오기 위해 사용합니다.
    """
    return requests.get("https://nomad-movies.nomadcoders.workers.dev/movies").json()

@function_tool
def get_movie_details(id:int):
    """id 에 해당하는 영화의 디테일한 정보를 조회하기 위해 사용합니다.
    Args:
        id: 영화 아이디
    """
    return requests.get(f"https://nomad-movies.nomadcoders.workers.dev/movies/{id}").json()

@function_tool
def get_movie_credits(id:int):
    """id 에 해당하는 영화의 출연진 및 제작진 정보를 가져옵니다.
    Args:
        id: 영화 아이디
    """
    return requests.get(f"https://nomad-movies.nomadcoders.workers.dev/movies/{id}/credits").json()

# %%
agent = Agent(
    name="Assistant",
    model="gpt-4o-mini",
    instructions="당신은 영화 정보를 소개하는 에이전트입니다.",
    tools=[get_popular_movies, get_movie_details, get_movie_credits]
)

# %%
result = await Runner.run(
    agent,
    "지금 인기 있는 영화가 무엇인지 알려줘"
)

# %%
result.final_output
# Out:
# '현재 인기 있는 영화는 다음과 같습니다:\n\n1. **Mercy**\n   - **개요**: 가까운 미래, 한 형사가 아내 살해 혐의로 재판을 받으며, AI 판사에게 자신의 무죄를 증명해야 하는 이야기를 다룹니다.\n   - **개봉일**: 2026-01-20\n   - **평점**: 7.1\n   - ![Mercy](https://image.tmdb.org/t/p/w780/pyok1kZJCfyuFapYXzHcy7BLlQa.jpg)\n\n2. **28 Years Later: The Bone Temple**\n   - **개요**: Dr. Kelson은 충격적인 새로운 관계에 휘말리며 세계를 변화시킬 수 있는 사건에 직면합니다.\n   - **개봉일**: 2026-01-14\n   - **평점**: 7.199\n   - ![28 Years Later: The Bone Temple](https://image.tmdb.org/t/p/w780/kK1BGkG3KAvWB0WMV1DfOx9yTMZ.jpg)\n\n3. **The Orphans**\n   - **개요**: 아동 보호소에서 자란 두 친구가 첫사랑의 비극적인 사고 후 다시 연결되며 복수의 여정을 시작합니다.\n   - **개봉일**: 2025-08-20\n   - **평점**: 6.043\n   - ![The Orphans](https://image.tmdb.org/t/p/w780/hP7mjZr2SVfjAorlRHTdV1XZmHY.jpg)\n\n4. **A Woman Scorned**\n   - **개요**: 가족과의 주말 여행 중, 주인공은 동생이 공격당하고 복수를 결심하게 됩니다.\n   - **개봉일**: 2025-06-09\n   - **평점**: 6.0\n   - ![A Woman Scorned](https://image.tmdb.org/t/p/w780/dlOSBiNULMPzKIze84LDjvEN9z1.jpg)\n\n5. **Deathstalker**\n   - **개요**: 강력한 검사가 저주받은 아뮬렛을 회수하면서 맞서는 이야기를 다룹니다.\n   - **개봉일**: 2025-10-10\n   - **평점**: 6.29\n   - ![Deathstalker](https://image.tmdb.org/t/p/w780/nEI3DnzQC1afAjJOAizx6UX27pL.jpg)\n\n더 많은 정보가 필요하시면 말씀해 주세요!'

# %%
result = await Runner.run(
    agent,
    "movie ID 550에 해당하는 영화가 무엇인지 알려줘"
)

result.final_output
# Out:
# '영화 ID 550에 해당하는 영화는 **"Fight Club"**입니다.\n\n### 영화 정보\n- **개봉일**: 1999년 10월 15일\n- **장르**: 드라마, 스릴러\n- **러닝타임**: 139분\n- **예산**: $63,000,000\n- **수익**: $100,853,753\n- **평점**: 8.4/10 (투표 수: 31,495)\n- **태그라인**: Mischief. Mayhem. Soap.\n- **언어**: 영어\n\n### 줄거리\nA ticking-time-bomb insomniac and a slippery soap salesman channel primal male aggression into a shocking new form of therapy. Their concept catches on, with underground "fight clubs" forming in every town, until an eccentric gets in the way and ignites an out-of-control spiral toward oblivion.\n\n### 제작사\n- Fox 2000 Pictures\n- Regency Enterprises\n- Linson Entertainment\n- 20th Century Fox\n- Taurus Film\n\n### 포스터 이미지\n![Fight Club Poster](https://image.tmdb.org/t/p/w780/pB8BM7pdSp6B6Ih7QZ4DrQ3PmJK.jpg)\n\n### 홈페이지\n[Fight Club 공식 사이트](http://www.foxmovies.com/movies/fight-club)\n\n이 영화에 대해 더 궁금한 점이 있으면 말씀해 주세요!'

# %%
result = await Runner.run(
    agent,
    "movie ID 550에 해당하는 영화에 누가 출연하는지 알려줘"
)

result.final_output
# Out:
# '영화 ID 550에 해당하는 영화 "Fight Club" (파이트 클럽)의 출연진은 다음과 같습니다:\n\n1. **Edward Norton** - Narrator\n   ![Edward Norton](https://image.tmdb.org/t/p/w185/8nytsqL59SFJTVYVrN72k6qkGgJ.jpg)\n\n2. **Brad Pitt** - Tyler Durden\n   ![Brad Pitt](https://image.tmdb.org/t/p/w185/cckcYc2v0yh1tc9QjRelptcOBko.jpg)\n\n3. **Helena Bonham Carter** - Marla Singer\n   ![Helena Bonham Carter](https://image.tmdb.org/t/p/w185/hJMbNSPJ2PCahsP3rNEU39C8GWU.jpg)\n\n4. **Meat Loaf** - Robert Paulson\n   ![Meat Loaf](https://image.tmdb.org/t/p/w185/7gKLR1u46OB8WJ6m06LemNBCMx6.jpg)\n\n5. **Jared Leto** - Angel Face\n   ![Jared Leto](https://image.tmdb.org/t/p/w185/ca3x0OfIKbJppZh8S1Alx3GfUZO.jpg)\n\n6. **Zach Grenier** - Richard Chesler (Regional Manager)\n   ![Zach Grenier](https://image.tmdb.org/t/p/w185/fSyQKZO39sUsqY283GXiScOg3Hi.jpg)\n\n7. **Holt McCallany** - The Mechanic\n   ![Holt McCallany](https://image.tmdb.org/t/p/w185/iRo9YUNMwZg4UCq7dapo0HydDmI.jpg)\n\n이 외에도 많은 배우들이 출연하고 있습니다. 필요하신 추가 출연진 정보가 있으면 말씀해 주세요!'
